# %%
# models to make today:
# model using only gender
# model using gender + class
# model using gender + class + age (binning)
# model using gender + class + age + name (synthetic feature)  (optional)
# make sure to attach tensorboard and screenshot training curve
import math
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn import metrics
from tensorflow.python.data import Dataset
from sklearn.model_selection import train_test_split

from IPython import display

# for sex_to_int() function
from sklearn.preprocessing import LabelEncoder

# make TensorFlow less verbose
tf.logging.set_verbosity(tf.logging.ERROR)

train_path = '../input/train.csv'
test_path = '../input/test.csv'

# %%
class get_data:
    def __init__(self, path, model_lst, is_train=True):
        self.model_lst = model_lst
        self.is_train = is_train
        
        self.feature = pd.read_csv(path)
        
        self.get_feature_label()
        self.deal_feature()
        
        self.get_model()
        self.split_t_v()
        
    def get_model(self):
        self.feature = self.feature[self.model_lst]
        self.get_dum()
        
#     def get_dum(self):
#         self.feature = pd.get_dummies(self.feature, dummy_na=True)
    
    def deal_feature(self):
        self.sex_to_int()
    
    def feature_eng(self):
        self.fill_nan()
        self.drop_cols()
        self.sex_to_int()
    
    def get_feature_label(self):
        if self.is_train:
            self.label = self.feature['Survived']
            self.feature = self.feature.drop('Survived', axis=1)
    
#     def fill_nan(self):
#         self.feature.fillna(0, inplace=True)
    
#     def drop_cols(self):
#         UNUSED_COLUMNS = ["Ticket", "Cabin", "Embarked", "Fare", "SibSp", "Parch", 'PassengerId']
#         self.feature = self.df.drop(UNUSED_COLUMNS, axis=1)
        
    def sex_to_int(self):
        gender = {'male': 1, 'female': 0}
        self.feature['Sex'] = [gender[item] for item in self.feature['Sex']]
#         self.feature['Sex'][self.feature['Sex'] == 'male'] = 1
#         self.feature['Sex'][self.feature['Sex'] == 'female'] = 0
        
    def get_dum(self):
        columns = ["Pclass"]
        for column in columns:
            self.feature = pd.concat([self.feature, pd.get_dummies(self.feature[column], prefix=column)], axis=1)
            self.feature = self.feature.drop(column, axis=1)
            
    def split_t_v(self):
        self.ts_f, self.vs_f, self.ts_l, self.vs_l = \
        train_test_split(
            self.feature,
            self.label,
            test_size=0.2,
            random_state=42
        )

# %%
class create_model:
    def __init__(
        self,
        feature,
        learning_rate=0.3,
        steps=10,
        periods=30,
        batch_size=100,
        save_model=True,
        load_model=False,
        save_model_dir='./default_model',
        load_model_dir='./default_model',
        bin_age=False
    ):
        self.feature = feature
        self.learning_rate = learning_rate
        self.steps = steps
        self.periods = periods
        self.batch_size = batch_size
        self.bin_age = bin_age
        
        self.save_model = save_model
        self.save_model_dir = save_model_dir
        self.load_model = load_model
        self.load_model_dir = load_model_dir
        
        self.create_optimizer()
        
        # create model by dict
        model_par = dict(
            feature_columns = self.get_feature_cols(),
            optimizer = self.optimizer,
            n_classes = 2
        )
        if self.save_model:
            model_par['model_dir'] = self.save_model_dir
        if self.load_model:
            model_par['warm_start_from'] = self.load_model_dir
        self.model = tf.estimator.LinearClassifier(**model_par)
        
    
#         self.model = tf.estimator.LinearRegressor(
#             feature_columns = self.get_feature_cols(),
#             optimizer = self.optimizer
#         )
        print('create model!')
        
    def get_feature_cols(self):
        tmp_feature = [tf.feature_column.numeric_column(my_feature) for my_feature in self.feature]
        if self.bin_age: # boolean:
            tmp_age = tf.feature_column.numeric_column("Age")
            bucketized_age = tf.feature_column.bucketized_column(
              tmp_age, boundaries=get_quantile_based_boundaries(
                input_features["Age"], 4))
            tmp_feature += [bucketized_age]
        return set(tmp_feature)
    
    def create_optimizer(self):
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        
        '''
        self.optimizer = tf.train.GradientDescentOptimizer(learning_rate=self.learning_rate)
        self.optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_opt, 2.0)
        '''
    
    def train(
        self,
        ts_f,
        ts_l,
        vs_f,
        vs_l
    ):
        self.ts_f = ts_f
        self.ts_l = ts_l
        self.vs_f = vs_f
        self.vs_l = vs_l
        self.create_input_fn()
        
        steps_per_period = self.steps / self.periods
        print('start training...')
        for period in range(self.periods):
#             print(" period %02d start" % (period))
            train = self.model.train(
                input_fn=self.train_input_fn,
                steps=steps_per_period
            )
#             evaluate_train = self.model.evaluate(
#                 input_fn=self.train_eval_fn
#             )
            evaluate_vali = self.model.evaluate(
                input_fn=self.vali_eval_fn
            )
            
#             print(train)
#             print(evaluate_train)
            print(evaluate_vali)
            print('\n')
            
#             print(" period %02d finish" % (period))
        print("Model training finished.")
        
    def create_input_fn(self):
        self.train_input_fn = lambda: self.my_input_fn(self.ts_f, self.ts_l, batch_size=self.batch_size)
        self.train_eval_fn = lambda: self.my_input_fn(self.ts_f, self.ts_l, shuffle=True, num_epochs=1)
        self.vali_eval_fn = lambda: self.my_input_fn(self.vs_f, self.vs_l, shuffle=True, num_epochs=1)
        
    def my_input_fn(self, features, targets, batch_size=1, shuffle=True, num_epochs=None):
        # Convert pandas data into a dict of np arrays.
        features = {key:np.array(value) for key,value in dict(features).items()}
        # Construct a dataset, and configure batching/repeating.
        ds = Dataset.from_tensor_slices((features,targets)) # warning: 2GB limit
        ds = ds.batch(batch_size).repeat(num_epochs)
        # Shuffle the data, if specified.
        if shuffle:
            ds = ds.shuffle(42)
        # Return the next batch of data.
        features, labels = ds.make_one_shot_iterator().get_next()
        return features, labels
    
    def predict(self, test_df):
        print('predict')

# %%
model_gender = ['Sex']
model_gender_class = ['Sex', 'Pclass']
model_gender_class_age = ['Sex', 'Pclass', 'Age']
model_gender_class_age_name = ['Sex', 'Pclass', 'Age', 'Name']

data = get_data(train_path, model_gender_class)
# test = get_data(test_path)
# data.get_model(model_gender)
data.ts_f.head(5)
# data.label.head(5)
# print(data.feature['Sex'].isnull().count())
# print(data.feature['Pclass'].isnull().any())
# print(data.feature['Age'].isna().sum())
# print(data.feature['Name'].isnull().any())
# Out:
#      Sex  Pclass_1  Pclass_2  Pclass_3
# 331    1         1         0         0
# 733    1         0         1         0
# 382    1         0         0         1
# 704    1         0         0         1
# 813    0         0         0         1

# %%
model = create_model(
    feature=data.feature,
    learning_rate=0.08,
#     save_model=False
    save_model_dir='./model/gc_v0'
)
# Out:
# create model!

# %%
print(data.ts_f.count(), '\n')
print('shape', data.ts_f.shape, '\n')

print(data.ts_l.count(), '\n')
print('shape', data.ts_l.shape, '\n')

print(data.vs_f.count(), '\n')
print('shape', data.vs_f.shape, '\n')

print(data.vs_l.count(), '\n')
print('shape', data.vs_l.shape, '\n')
# Out:
# Sex         712
# Pclass_1    712
# Pclass_2    712
# Pclass_3    712
# dtype: int64
#
# shape (712, 4)
#
# 712
#
# shape (712,)
#
# Sex         179
# Pclass_1    179
# Pclass_2    179
# Pclass_3    179
# dtype: int64
#
# shape (179, 4)
#
# 179
#
# shape (179,)

# %%
model.train(
    data.ts_f,
    data.ts_l,
    data.vs_f,
    data.vs_l
)
# Out:
# start training...
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.83301157, 'auc_precision_recall': 0.8505671, 'average_loss': 0.66453004, 'label/mean': 0.41340783, 'loss': 0.66453004, 'precision': 0.0, 'prediction/mean': 0.4537972, 'recall': 0.0, 'global_step': 1}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.8184041, 'auc_precision_recall': 0.7965144, 'average_loss': 0.6408087, 'label/mean': 0.41340783, 'loss': 0.6408087, 'precision': 0.0, 'prediction/mean': 0.41327906, 'recall': 0.0, 'global_step': 2}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.8249036, 'auc_precision_recall': 0.8000878, 'average_loss': 0.62603396, 'label/mean': 0.41340783, 'loss': 0.62603396, 'precision': 0.0, 'prediction/mean': 0.38386574, 'recall': 0.0, 'global_step': 3}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.8339126, 'auc_precision_recall': 0.825622, 'average_loss': 0.6145312, 'label/mean': 0.41340783, 'loss': 0.6145312, 'precision': 0.0, 'prediction/mean': 0.35619232, 'recall': 0.0, 'global_step': 4}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.8429216, 'auc_precision_recall': 0.8322319, 'average_loss': 0.6023798, 'label/mean': 0.41340783, 'loss': 0.6023798, 'precision': 0.0, 'prediction/mean': 0.3436537, 'recall': 0.0, 'global_step': 5}
#
#
# {'accuracy': 0.7206704, 'accuracy_baseline': 0.5865922, 'auc': 0.8429216, 'auc_precision_recall': 0.8322318, 'average_loss': 0.59096295, 'label/mean': 0.41340783, 'loss': 0.59096295, 'precision': 1.0, 'prediction/mean': 0.33726776, 'recall': 0.3243243, 'global_step': 6}
#
#
# {'accuracy': 0.7206704, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5786841, 'label/mean': 0.41340783, 'loss': 0.5786841, 'precision': 1.0, 'prediction/mean': 0.33786494, 'recall': 0.3243243, 'global_step': 7}
#
#
# {'accuracy': 0.7206704, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5672402, 'label/mean': 0.41340783, 'loss': 0.5672402, 'precision': 1.0, 'prediction/mean': 0.34178618, 'recall': 0.3243243, 'global_step': 8}
#
#
# {'accuracy': 0.7206704, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5566919, 'label/mean': 0.41340783, 'loss': 0.5566919, 'precision': 1.0, 'prediction/mean': 0.34823868, 'recall': 0.3243243, 'global_step': 9}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.8153797, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5469608, 'label/mean': 0.41340783, 'loss': 0.5469608, 'precision': 0.9, 'prediction/mean': 0.35623905, 'recall': 0.4864865, 'global_step': 10}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5384229, 'label/mean': 0.41340783, 'loss': 0.5384229, 'precision': 0.9, 'prediction/mean': 0.36533424, 'recall': 0.4864865, 'global_step': 11}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.53056103, 'label/mean': 0.41340783, 'loss': 0.53056103, 'precision': 0.9, 'prediction/mean': 0.37730053, 'recall': 0.4864865, 'global_step': 12}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5240968, 'label/mean': 0.41340783, 'loss': 0.5240968, 'precision': 0.9, 'prediction/mean': 0.38499627, 'recall': 0.4864865, 'global_step': 13}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.8153797, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5187273, 'label/mean': 0.41340783, 'loss': 0.5187273, 'precision': 0.71014494, 'prediction/mean': 0.38855404, 'recall': 0.6621622, 'global_step': 14}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.51358473, 'label/mean': 0.41340783, 'loss': 0.51358473, 'precision': 0.71014494, 'prediction/mean': 0.3925189, 'recall': 0.6621622, 'global_step': 15}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.50864494, 'label/mean': 0.41340783, 'loss': 0.50864494, 'precision': 0.71014494, 'prediction/mean': 0.39659557, 'recall': 0.6621622, 'global_step': 16}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.5044556, 'label/mean': 0.41340783, 'loss': 0.5044556, 'precision': 0.71014494, 'prediction/mean': 0.3987604, 'recall': 0.6621622, 'global_step': 17}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.50087774, 'label/mean': 0.41340783, 'loss': 0.50087774, 'precision': 0.71014494, 'prediction/mean': 0.40157387, 'recall': 0.6621622, 'global_step': 18}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.49725875, 'label/mean': 0.41340783, 'loss': 0.49725875, 'precision': 0.71014494, 'prediction/mean': 0.4026844, 'recall': 0.6621622, 'global_step': 19}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.49357414, 'label/mean': 0.41340783, 'loss': 0.49357414, 'precision': 0.71014494, 'prediction/mean': 0.402253, 'recall': 0.6621622, 'global_step': 20}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.8153797, 'auc_precision_recall': 0.81162465, 'average_loss': 0.49050763, 'label/mean': 0.41340783, 'loss': 0.49050763, 'precision': 0.71014494, 'prediction/mean': 0.39824545, 'recall': 0.6621622, 'global_step': 21}
#
#
# {'accuracy': 0.74860334, 'accuracy_baseline': 0.5865922, 'auc': 0.81537974, 'auc_precision_recall': 0.81162465, 'average_loss': 0.4879334, 'label/mean': 0.41340783, 'loss': 0.4879334, 'precision': 0.71014494, 'prediction/mean': 0.39608744, 'recall': 0.6621622, 'global_step': 22}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.84292156, 'auc_precision_recall': 0.8322318, 'average_loss': 0.4852922, 'label/mean': 0.41340783, 'loss': 0.4852922, 'precision': 0.9, 'prediction/mean': 0.39321482, 'recall': 0.4864865, 'global_step': 23}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.84292156, 'auc_precision_recall': 0.8322319, 'average_loss': 0.48239967, 'label/mean': 0.41340783, 'loss': 0.48239967, 'precision': 0.9, 'prediction/mean': 0.39154667, 'recall': 0.4864865, 'global_step': 24}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.8429216, 'auc_precision_recall': 0.8322319, 'average_loss': 0.47994658, 'label/mean': 0.41340783, 'loss': 0.47994658, 'precision': 0.9, 'prediction/mean': 0.38888925, 'recall': 0.4864865, 'global_step': 25}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.8429216, 'auc_precision_recall': 0.8322319, 'average_loss': 0.47749943, 'label/mean': 0.41340783, 'loss': 0.47749943, 'precision': 0.9, 'prediction/mean': 0.38603002, 'recall': 0.4864865, 'global_step': 26}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.8429216, 'auc_precision_recall': 0.8322318, 'average_loss': 0.47512636, 'label/mean': 0.41340783, 'loss': 0.47512636, 'precision': 0.9, 'prediction/mean': 0.383191, 'recall': 0.4864865, 'global_step': 27}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.84292156, 'auc_precision_recall': 0.8322318, 'average_loss': 0.47292238, 'label/mean': 0.41340783, 'loss': 0.47292238, 'precision': 0.9, 'prediction/mean': 0.3830947, 'recall': 0.4864865, 'global_step': 28}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.8429216, 'auc_precision_recall': 0.8322319, 'average_loss': 0.47066933, 'label/mean': 0.41340783, 'loss': 0.47066933, 'precision': 0.9, 'prediction/mean': 0.38439366, 'recall': 0.4864865, 'global_step': 29}
#
#
# {'accuracy': 0.76536316, 'accuracy_baseline': 0.5865922, 'auc': 0.84852004, 'auc_precision_recall': 0.8486389, 'average_loss': 0.46855342, 'label/mean': 0.41340783, 'loss': 0.46855342, 'precision': 0.9, 'prediction/mean': 0.38541737, 'recall': 0.4864865, 'global_step': 30}
#
#
# Model training finished.
