# %%
# models to make today:
# model using only gender
# model using gender + class
# model using gender + class + age (binning)
# model using gender + class + age + name (synthetic feature)  (optional)
# make sure to attach tensorboard and screenshot training curve
import math
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn import metrics
from tensorflow.python.data import Dataset
from sklearn.model_selection import train_test_split

from IPython import display

# for sex_to_int() function
from sklearn.preprocessing import LabelEncoder

# make TensorFlow less verbose
tf.logging.set_verbosity(tf.logging.ERROR)

train_path = '../input/train.csv'
test_path = '../input/test.csv'

# %%
class get_data:
    def __init__(self, path, model_lst, is_train=True):
        self.model_lst = model_lst
        self.is_train = is_train
        
        self.feature = pd.read_csv(path)
        
        self.get_feature_label()
        self.deal_feature()
        
        self.get_model()
        self.split_t_v()
        
    def get_model(self):
        self.feature = self.feature[self.model_lst]
        self.get_dum()
        
    def get_dum(self):
        self.feature = pd.get_dummies(self.feature, dummy_na=True)
    
    def deal_feature(self):
        self.sex_to_int()
    
    def feature_eng(self):
        self.fill_nan()
        self.drop_cols()
        self.sex_to_int()
    
    def get_feature_label(self):
        if self.is_train:
            self.label = self.feature['Survived']
            self.feature = self.feature.drop('Survived', axis=1)
    
#     def fill_nan(self):
#         self.feature.fillna(0, inplace=True)
    
#     def drop_cols(self):
#         UNUSED_COLUMNS = ["Ticket", "Cabin", "Embarked", "Fare", "SibSp", "Parch", 'PassengerId']
#         self.feature = self.df.drop(UNUSED_COLUMNS, axis=1)
        
    def sex_to_int(self):
        gender = {'male': 1, 'female': 0}
        self.feature['Sex'] = [gender[item] for item in self.feature['Sex']]
#         self.feature['Sex'][self.feature['Sex'] == 'male'] = 1
#         self.feature['Sex'][self.feature['Sex'] == 'female'] = 0
        
#     def get_dum(self):
#         columns = ["Pclass"]
#         for column in columns:
#             data = pd.concat([data, pd.get_dummies(data[column], prefix=column)], axis=1)
#             data = data.drop(column, axis=1)
            
    def split_t_v(self):
        self.ts_f, self.vs_f, self.ts_l, self.vs_l = \
        train_test_split(
            self.feature,
            self.label,
            test_size=0.2,
            random_state=42
        )

# %%
class create_model:
    def __init__(
        self,
        feature,
        learning_rate=0.3,
        steps=10,
        periods=30,
        batch_size=100,
        save_model=True,
        load_model=False,
        save_model_dir='./default_model',
        load_model_dir='./default_model'
    ):
        self.feature = feature
        self.learning_rate = learning_rate
        self.steps = steps
        self.periods = periods
        self.batch_size = batch_size
        
        self.save_model = save_model
        self.save_model_dir = save_model_dir
        self.load_model = load_model
        self.load_model_dir = load_model_dir
        
        self.create_optimizer()
        
        # create model by dict
        model_par = dict(
            feature_columns = self.get_feature_cols(),
            optimizer = self.optimizer,
            n_classes = 2
        )
        if self.save_model:
            model_par['model_dir'] = self.save_model_dir
        if self.load_model:
            model_par['warm_start_from'] = self.load_model_dir
        self.model = tf.estimator.LinearClassifier(**model_par)
        
    
#         self.model = tf.estimator.LinearRegressor(
#             feature_columns = self.get_feature_cols(),
#             optimizer = self.optimizer
#         )
        print('create model!')
        
    def get_feature_cols(self):
        tmp_feature = [tf.feature_column.numeric_column(my_feature) for my_feature in self.feature]
#         if bin_age: # boolean:
#             tmp_age = tf.feature_column.numeric_column("Age")
#             bucketized_age = tf.feature_column.bucketized_column(
#               tmp_age, boundaries=get_quantile_based_boundaries(
#                 input_features["Age"], 4))
#             tmp_feature += [bucketized_age]
        return set(tmp_feature)
    
    def create_optimizer(self):
        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        
        '''
        self.optimizer = tf.train.GradientDescentOptimizer(learning_rate=self.learning_rate)
        self.optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_opt, 2.0)
        '''
    
    def train(
        self,
        ts_f,
        ts_l,
        vs_f,
        vs_l
    ):
        self.ts_f = ts_f
        self.ts_l = ts_l
        self.vs_f = vs_f
        self.vs_l = vs_l
        self.create_input_fn()
        
        steps_per_period = self.steps / self.periods
        print('start training...')
        for period in range(self.periods):
#             print(" period %02d start" % (period))
            train = self.model.train(
                input_fn=self.train_input_fn,
                steps=steps_per_period
            )
#             evaluate_train = self.model.evaluate(
#                 input_fn=self.train_eval_fn
#             )
            evaluate_vali = self.model.evaluate(
                input_fn=self.vali_eval_fn
            )
            
#             print(train)
#             print(evaluate_train)
            print(evaluate_vali)
            print('\n')
            
#             print(" period %02d finish" % (period))
        print("Model training finished.")
        
    def create_input_fn(self):
        self.train_input_fn = lambda: self.my_input_fn(self.ts_f, self.ts_l, batch_size=self.batch_size)
        self.train_eval_fn = lambda: self.my_input_fn(self.ts_f, self.ts_l, shuffle=True, num_epochs=1)
        self.vali_eval_fn = lambda: self.my_input_fn(self.vs_f, self.vs_l, shuffle=True, num_epochs=1)
        
    def my_input_fn(self, features, targets, batch_size=1, shuffle=True, num_epochs=None):
        # Convert pandas data into a dict of np arrays.
        features = {key:np.array(value) for key,value in dict(features).items()}
        # Construct a dataset, and configure batching/repeating.
        ds = Dataset.from_tensor_slices((features,targets)) # warning: 2GB limit
        ds = ds.batch(batch_size).repeat(num_epochs)
        # Shuffle the data, if specified.
        if shuffle:
            ds = ds.shuffle(42)
        # Return the next batch of data.
        features, labels = ds.make_one_shot_iterator().get_next()
        return features, labels
    
    def predict(self, test_df):
        print('predict')

# %%
model_gender = ['Sex']
model_gender_class = ['Sex', 'Pclass']
model_gender_class_age = ['Sex', 'Pclass', 'Age']
model_gender_class_age_name = ['Sex', 'Pclass', 'Age', 'Name']

data = get_data(train_path, model_gender)
# test = get_data(test_path)
# data.get_model(model_gender)
data.ts_f.head(5)
# data.label.head(5)
# print(data.feature['Sex'].isnull().count())
# print(data.feature['Pclass'].isnull().any())
# print(data.feature['Age'].isna().sum())
# print(data.feature['Name'].isnull().any())
# Out:
#      Sex
# 331    1
# 733    1
# 382    1
# 704    1
# 813    0

# %%
model = create_model(
    feature=data.feature,
    learning_rate=0.08,
#     save_model=False
    save_model_dir='./model/test_v10'
)
# Out:
# create model!

# %%
print(data.ts_f.count(), '\n')
print('shape', data.ts_f.shape, '\n')

print(data.ts_l.count(), '\n')
print('shape', data.ts_l.shape, '\n')

print(data.vs_f.count(), '\n')
print('shape', data.vs_f.shape, '\n')

print(data.vs_l.count(), '\n')
print('shape', data.vs_l.shape, '\n')
# Out:
# Sex    712
# dtype: int64
#
# shape (712, 1)
#
# 712
#
# shape (712,)
#
# Sex    179
# dtype: int64
#
# shape (179, 1)
#
# 179
#
# shape (179,)

# %%
model.train(
    data.ts_f,
    data.ts_l,
    data.vs_f,
    data.vs_l
)
# Out:
# start training...
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.67374355, 'label/mean': 0.41340783, 'loss': 0.67374355, 'precision': 0.0, 'prediction/mean': 0.46776608, 'recall': 0.0, 'global_step': 1}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6616638, 'label/mean': 0.41340783, 'loss': 0.6616638, 'precision': 0.0, 'prediction/mean': 0.44262078, 'recall': 0.0, 'global_step': 2}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6518445, 'label/mean': 0.41340783, 'loss': 0.6518445, 'precision': 0.0, 'prediction/mean': 0.41630298, 'recall': 0.0, 'global_step': 3}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6443687, 'label/mean': 0.41340783, 'loss': 0.6443687, 'precision': 0.0, 'prediction/mean': 0.39228302, 'recall': 0.0, 'global_step': 4}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6399598, 'label/mean': 0.41340783, 'loss': 0.6399598, 'precision': 0.0, 'prediction/mean': 0.37103897, 'recall': 0.0, 'global_step': 5}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.63734007, 'label/mean': 0.41340783, 'loss': 0.63734007, 'precision': 0.0, 'prediction/mean': 0.35097143, 'recall': 0.0, 'global_step': 6}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.63491416, 'label/mean': 0.41340783, 'loss': 0.63491416, 'precision': 0.0, 'prediction/mean': 0.3365213, 'recall': 0.0, 'global_step': 7}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6331335, 'label/mean': 0.41340783, 'loss': 0.6331335, 'precision': 0.0, 'prediction/mean': 0.32343355, 'recall': 0.0, 'global_step': 8}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6324836, 'label/mean': 0.41340783, 'loss': 0.6324836, 'precision': 0.0, 'prediction/mean': 0.31155056, 'recall': 0.0, 'global_step': 9}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.63017523, 'label/mean': 0.41340783, 'loss': 0.63017523, 'precision': 0.0, 'prediction/mean': 0.30438018, 'recall': 0.0, 'global_step': 10}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6262052, 'label/mean': 0.41340783, 'loss': 0.6262052, 'precision': 0.0, 'prediction/mean': 0.30196285, 'recall': 0.0, 'global_step': 11}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.62172735, 'label/mean': 0.41340783, 'loss': 0.62172735, 'precision': 0.0, 'prediction/mean': 0.30205318, 'recall': 0.0, 'global_step': 12}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.61624205, 'label/mean': 0.41340783, 'loss': 0.61624205, 'precision': 0.0, 'prediction/mean': 0.30456966, 'recall': 0.0, 'global_step': 13}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.61070293, 'label/mean': 0.41340783, 'loss': 0.61070293, 'precision': 0.0, 'prediction/mean': 0.30734888, 'recall': 0.0, 'global_step': 14}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.6050558, 'label/mean': 0.41340783, 'loss': 0.6050558, 'precision': 0.0, 'prediction/mean': 0.3117541, 'recall': 0.0, 'global_step': 15}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.59896386, 'label/mean': 0.41340783, 'loss': 0.59896386, 'precision': 0.0, 'prediction/mean': 0.31697217, 'recall': 0.0, 'global_step': 16}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5926564, 'label/mean': 0.41340783, 'loss': 0.5926564, 'precision': 0.0, 'prediction/mean': 0.32276943, 'recall': 0.0, 'global_step': 17}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.58632475, 'label/mean': 0.41340783, 'loss': 0.58632475, 'precision': 0.0, 'prediction/mean': 0.32964686, 'recall': 0.0, 'global_step': 18}
#
#
# {'accuracy': 0.5865922, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5805146, 'label/mean': 0.41340783, 'loss': 0.5805146, 'precision': 0.0, 'prediction/mean': 0.3372064, 'recall': 0.0, 'global_step': 19}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5753175, 'label/mean': 0.41340783, 'loss': 0.5753175, 'precision': 0.7536232, 'prediction/mean': 0.34490472, 'recall': 0.7027027, 'global_step': 20}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5706984, 'label/mean': 0.41340783, 'loss': 0.5706984, 'precision': 0.7536232, 'prediction/mean': 0.35290912, 'recall': 0.7027027, 'global_step': 21}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5665917, 'label/mean': 0.41340783, 'loss': 0.5665917, 'precision': 0.7536232, 'prediction/mean': 0.35999683, 'recall': 0.7027027, 'global_step': 22}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.56302226, 'label/mean': 0.41340783, 'loss': 0.56302226, 'precision': 0.7536232, 'prediction/mean': 0.36708197, 'recall': 0.7027027, 'global_step': 23}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5596308, 'label/mean': 0.41340783, 'loss': 0.5596308, 'precision': 0.7536232, 'prediction/mean': 0.3749246, 'recall': 0.7027027, 'global_step': 24}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5568138, 'label/mean': 0.41340783, 'loss': 0.5568138, 'precision': 0.7536232, 'prediction/mean': 0.38229224, 'recall': 0.7027027, 'global_step': 25}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.55445975, 'label/mean': 0.41340783, 'loss': 0.55445975, 'precision': 0.7536232, 'prediction/mean': 0.38834497, 'recall': 0.7027027, 'global_step': 26}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5522363, 'label/mean': 0.41340783, 'loss': 0.5522363, 'precision': 0.7536232, 'prediction/mean': 0.3918443, 'recall': 0.7027027, 'global_step': 27}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.55007094, 'label/mean': 0.41340783, 'loss': 0.55007094, 'precision': 0.7536232, 'prediction/mean': 0.39589345, 'recall': 0.7027027, 'global_step': 28}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.54822093, 'label/mean': 0.41340783, 'loss': 0.54822093, 'precision': 0.7536232, 'prediction/mean': 0.39920917, 'recall': 0.7027027, 'global_step': 29}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.54655313, 'label/mean': 0.41340783, 'loss': 0.54655313, 'precision': 0.7536232, 'prediction/mean': 0.40148807, 'recall': 0.7027027, 'global_step': 30}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.54491067, 'label/mean': 0.41340783, 'loss': 0.54491067, 'precision': 0.7536232, 'prediction/mean': 0.40424365, 'recall': 0.7027027, 'global_step': 31}
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5434092, 'label/mean': 0.41340783, 'loss': 0.5434092, 'precision': 0.7536232, 'prediction/mean': 0.40599018, 'recall': 0.7027027, 'global_step': 32}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.542071, 'label/mean': 0.41340783, 'loss': 0.542071, 'precision': 0.7536232, 'prediction/mean': 0.40645117, 'recall': 0.7027027, 'global_step': 33}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.540905, 'label/mean': 0.41340783, 'loss': 0.540905, 'precision': 0.7536232, 'prediction/mean': 0.40631974, 'recall': 0.7027027, 'global_step': 34}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5398918, 'label/mean': 0.41340783, 'loss': 0.5398918, 'precision': 0.7536232, 'prediction/mean': 0.40569296, 'recall': 0.7027027, 'global_step': 35}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.53863245, 'label/mean': 0.41340783, 'loss': 0.53863245, 'precision': 0.7536232, 'prediction/mean': 0.40368858, 'recall': 0.7027027, 'global_step': 36}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5374094, 'label/mean': 0.41340783, 'loss': 0.5374094, 'precision': 0.7536232, 'prediction/mean': 0.4027612, 'recall': 0.7027027, 'global_step': 37}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5361984, 'label/mean': 0.41340783, 'loss': 0.5361984, 'precision': 0.7536232, 'prediction/mean': 0.399715, 'recall': 0.7027027, 'global_step': 38}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.53518385, 'label/mean': 0.41340783, 'loss': 0.53518385, 'precision': 0.7536232, 'prediction/mean': 0.39630613, 'recall': 0.7027027, 'global_step': 39}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5342047, 'label/mean': 0.41340783, 'loss': 0.5342047, 'precision': 0.7536232, 'prediction/mean': 0.39450765, 'recall': 0.7027027, 'global_step': 40}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5332255, 'label/mean': 0.41340783, 'loss': 0.5332255, 'precision': 0.7536232, 'prediction/mean': 0.3933334, 'recall': 0.7027027, 'global_step': 41}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.53247315, 'label/mean': 0.41340783, 'loss': 0.53247315, 'precision': 0.7536232, 'prediction/mean': 0.39191127, 'recall': 0.7027027, 'global_step': 42}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.53165674, 'label/mean': 0.41340783, 'loss': 0.53165674, 'precision': 0.7536232, 'prediction/mean': 0.39212713, 'recall': 0.7027027, 'global_step': 43}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5310266, 'label/mean': 0.41340783, 'loss': 0.5310266, 'precision': 0.7536232, 'prediction/mean': 0.39204842, 'recall': 0.7027027, 'global_step': 44}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.53050256, 'label/mean': 0.41340783, 'loss': 0.53050256, 'precision': 0.7536232, 'prediction/mean': 0.39036936, 'recall': 0.7027027, 'global_step': 45}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5301053, 'label/mean': 0.41340783, 'loss': 0.5301053, 'precision': 0.7536232, 'prediction/mean': 0.38809928, 'recall': 0.7027027, 'global_step': 46}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.52956754, 'label/mean': 0.41340783, 'loss': 0.52956754, 'precision': 0.7536232, 'prediction/mean': 0.38780972, 'recall': 0.7027027, 'global_step': 47}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.5291098, 'label/mean': 0.41340783, 'loss': 0.5291098, 'precision': 0.7536232, 'prediction/mean': 0.3881816, 'recall': 0.7027027, 'global_step': 48}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.52862215, 'label/mean': 0.41340783, 'loss': 0.52862215, 'precision': 0.7536232, 'prediction/mean': 0.38788852, 'recall': 0.7027027, 'global_step': 49}
#
#
# {'accuracy': 0.7821229, 'accuracy_baseline': 0.5865922, 'auc': 0.77039903, 'auc_precision_recall': 0.7896155, 'average_loss': 0.52798617, 'label/mean': 0.41340783, 'loss': 0.52798617, 'precision': 0.7536232, 'prediction/mean': 0.38942918, 'recall': 0.7027027, 'global_step': 50}
#
#
# Model training finished.
